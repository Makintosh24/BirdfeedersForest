# %% [markdown]
# <a href="https://colab.research.google.com/github/Makintosh24/BirdfeedersForest/blob/main/Windfarms_energy_in_Paldinsky_windfarm%2C_Estonia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Enefit Green operates 19 wind farms in Estonia
with a total capacity of 280 MW.
The largest of these are Aulepa I (which has a capacity of 39 MW),
Narva (a capacity of 39 MW), Aseriaru (24 MW capacity),
 Paldiski I and II (both 22.5 MW), Purtse (21 MW), Viru-Nigula (21) and Pakri (18.4 MW)

# %%
Paldiski Wind Farm is a 45MW onshore wind power project. It is located in Harju, Estonia.
The project generates 52,000MWh electricity and supplies enough clean energy
to power 21,000 households, offsetting 49,000t of carbon dioxide emissions (CO2) a year.



I download from the website https://www.windfinder.com/forecast/paldiski the data about the wind speed and wind gusts on

# %%
import numpy as np
import pandas as pd
# Out:
#   File "<ipython-input-3-2ca198c1cf65>", line 1
#     https://www.windfinder.com/forecast/paldiski
#           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
WindSpeedmean=pd.read_csv("WindSpeed mean over Estonia.csv")
WindSpeedmean
# Out:
#      val  perc  sel_perc
# 0   8.72     2         2
# 1   8.60     4         4
# 2   8.49     6         6
# 3   8.37     8         8
# 4   8.26    10        10
# 5   8.16    12        12
# 6   8.07    14        14
# 7   8.00    16        16
# 8   7.94    18        18
# 9   7.88    20        20
# 10  7.84    22        22
# 11  7.79    24        24
# 12  7.75    26        26
# 13  7.72    28        28
# 14  7.69    30        30
# 15  7.66    32        32
# 16  7.63    34        34
# 17  7.60    36        36
# 18  7.58    38        38
# 19  7.55    40        40
# 20  7.53    42        42
# 21  7.51    44        44
# 22  7.49    46        46
# 23  7.47    48        48
# 24  7.45    50        50
# 25  7.43    52        52
# 26  7.41    54        54
# 27  7.39    56        56
# 28  7.37    58        58
# 29  7.36    60        60
# 30  7.34    62        62
# 31  7.32    64        64
# 32  7.31    66        66
# 33  7.29    68        68
# 34  7.28    70        70
# 35  7.26    72        72
# ...

# %%
PowerDensitymean=pd.read_csv("powerDensity mean over Estonia.csv")
PowerDensitymean
# Out:
#        val  perc  sel_perc
# 0   687.39     2         2
# 1   656.35     4         4
# 2   632.57     6         6
# 3   608.68     8         8
# 4   585.56    10        10
# 5   564.22    12        12
# 6   545.57    14        14
# 7   529.66    16        16
# 8   516.18    18        18
# 9   504.60    20        20
# 10  494.49    22        22
# 11  485.55    24        24
# 12  477.53    26        26
# 13  470.28    28        28
# 14  463.66    30        30
# 15  457.59    32        32
# 16  451.98    34        34
# 17  446.75    36        36
# 18  441.85    38        38
# 19  437.25    40        40
# 20  432.89    42        42
# 21  428.77    44        44
# 22  424.85    46        46
# 23  421.12    48        48
# 24  417.56    50        50
# 25  414.14    52        52
# 26  410.85    54        54
# 27  407.68    56        56
# 28  404.61    58        58
# 29  401.63    60        60
# 30  398.75    62        62
# 31  395.94    64        64
# 32  393.21    66        66
# ...

# %%
plt.plot(WindSpeedmean.val, PowerDensitymean.val)
